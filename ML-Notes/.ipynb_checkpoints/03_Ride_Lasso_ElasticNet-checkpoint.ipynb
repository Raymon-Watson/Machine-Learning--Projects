# %% [markdown]
# # 03 Ridge, Lasso, and Elastic Net
#
# - Ridge
# $$ \min_\beta \left[ \sum_i(y_i-\hat y_i)^2+ \lambda\sum_j\beta_j^2 \right] $$
# - Lasso
# $$ \min_\beta \left[ \sum_i(y_i-\hat y_i)^2+ \lambda\sum_j|\beta_j| \right] $$
# - Regularization
# - Why regularization reduces variance
# - Bias–variance tradeoff
# - L1 vs L2 penalties
# - Why Ridge shrinks coefficients
# - Why Lasso can produce exactly zero coefficients
# - Feature selection with Lasso
# - Elastic Net as a combination
# - Effect of \(\lambda\)
# - Why features must generally be standardized
# - Selecting \(\lambda\) using cross-validation
