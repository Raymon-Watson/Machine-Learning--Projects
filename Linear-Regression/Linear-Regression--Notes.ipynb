# %% [markdown]
# # Linear Regression Notes
#
# In this notebook, I will give a general overview of Linear Regression with application in Python. This will be in the context of data analysis, so the presentation will additionally contain details on methods for extracting information from data using pandas.
#
# This notebook will therefore additionally contain relevant code that can be repurposed for future linear regression problems.
#
# A general overview of the pipeline used for applying linear regression to data is as follows:
# - Import data to pandas DataFrame
# - Exploratory data analysis
#     - Examine target variable
#     - Plot relevant data to find trends
#     - Examine correlations
# - Choose relevant X and y
# - Train/test split
# - Apply LinearRegression() from scikit-learn
# - .fit() to training data
# - .predict() to test data
# - MAE/RMSE/$R^2$
# - Plot predictions/residuals
# - Interpret results

# %% [markdown]
# ## Imports
# There are a handful of particularly useful libraries that we will use in our linear regression analysis, which I give details on here.

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Model evaluation
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %% [markdown]
# ### Data Manipulation
# First, we import the packages that will be essential for manipulating the imported data:
# ```python
# import pandas as pd
# import numpy as np
# ```
# *Pandas* is essential for importing the data to a DataFrame, which will allow us to investigate and structure our data. In particular, at the start we will use pandas in order to understand the data that we have been given as well as clean it if required.
#
# *Numpy* is generally necessary for all data analysis projects, since we will often need to make use of the various mathematical methods contained in this library.
#
# ### Visualization
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
# *matplotlib.pyplot* will be essential for visualising our data, and will be heavily used in the exploratory data analysis stage.
#
# *seaborn* will be utilized to generate the final figures, as it is much easier to make presentable figures using this library. Further, there are a handful of plotting methods available in seaborn that will aid in our data analysis.
#
#
# ### Machine Learning
# ```python
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
# ```
#
# ### Model Evaluation
#
#
# ```python
# from sklearn.metrics import (
#     mean_absolute_error,
#     mean_squared_error,
#     r2_score
# )
# ```
