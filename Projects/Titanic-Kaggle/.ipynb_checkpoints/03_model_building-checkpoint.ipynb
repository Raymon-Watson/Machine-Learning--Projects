# %% [markdown]
# # 03 Model Building and Evaluation
# Here is the list of the main models that we will test in this notebook:
# 1. Decision Tree
# 2. Random Forest
# 3. K-Nearest Neighbors (KNN)
# 4. Support Vector Machine (SVM)
# 5. Logistic Regression

# %% [markdown]
# ## 1. Import Libraries and Load Cleaned Data

# %%
# Core Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# Statistical Learning Models


# Model Validation
from sklearn.tree import DecisionTreeClassifier

# %%
# Load the cleaned dataset prepared in notebook 02
df = pd.read_csv("data/titanic_cleaned.csv")
print(df.shape)
df.head(10)
# Out:
# (891, 15)
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Fam  \
# 0            1         0       3    0  22.0      1      0   7.2500    1
# 1            2         1       1    1  38.0      1      0  71.2833    1
# 2            3         1       3    1  26.0      0      0   7.9250    0
# 3            4         1       1    1  35.0      1      0  53.1000    1
# 4            5         0       3    0  35.0      0      0   8.0500    0
# 5            6         0       3    0  28.0      0      0   8.4583    0
# 6            7         0       1    0  54.0      0      0  51.8625    0
# 7            8         0       3    0   2.0      3      1  21.0750    4
# 8            9         1       3    1  27.0      0      2  11.1333    2
# 9           10         1       2    1  14.0      1      0  30.0708    1
#
#    Embarked_Q  Embarked_S  AgeGroup_Teen  AgeGroup_Young Adult  \
# 0           0           1              0                     1
# ...

# %% [markdown]
# ## 2. Prepare Features and Target

# %%
X = df.drop("Survived", axis=1)
y = df["Survived"]

print(X.shape)
print(len(y))
# Out:
# (891, 14)
# 891

# %% [markdown]
# We now split the data into training and testing splits for our initial model evaluation. Note that we will stratify on y to make sure that both training and testing datasets contain the same proportion of the Survived label.

# %%
# Train/test split by 80/20 rule
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=100, stratify=y
)

# %% [markdown]
# ## 3. Train Models
